# %%
import matplotlib as mpl
import math 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../Data/Expendatures Teacher Inexperience Out of Cert and Core Index").dropna()

# %%
features = ['PER_FED_STATE_LOCAL_EXP', 'PER_TEACH_INEXP', 'PER_OUT_CERT', 'ABSENT_RATE'] # Not including the log
outcome = "CORE_INDEX"

# %%
for feature in features:
    sns.histplot(data=df, x=feature, hue = "SCHOOL_TYPE", kde = True)
    plt.savefig(f"Feature Histplot for {feature}.png")
    plt.show()
