# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Getting the two Regents Excel Files

# %%
are_df = pd.read_csv("../Data/SRC2022/Annual Regents Exams Toy Example.csv")

# %%
df = are_df[are_df["YEAR"] == 2021]
# df = df[are_df["SUBGROUP_NAME"].isin(["Male", "Female"])].dropna(subset=["PER_LEVEL1", "PER_LEVEL2"])
df_mf = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])]
df = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["All Students"])]

for column in ['PER_LEVEL1', 'PER_LEVEL2']:
    df[column] = df[column].astype("int64")

sns.scatterplot(data=df_mf, x="PER_LEVEL1", y="PER_LEVEL2", hue="SUBGROUP_NAME")
plt.show()
sns.scatterplot(data=df, x="PER_LEVEL1", y="PER_LEVEL2", hue="SUBGROUP_NAME")
plt.show()
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_13996\2923910266.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_mf = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])]
# C:\Users\natha\AppData\Local\Temp\ipykernel_13996\2923910266.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_mf = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])]
# C:\Users\natha\AppData\Local\Temp\ipykernel_13996\2923910266.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["All Students"])]
# ...

# %%
df["PER_LEVEL1"].describe()
# Out:
# count    718.000000
# mean      14.589136
# std       12.499361
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       20.000000
# max       76.000000
# Name: PER_LEVEL1, dtype: float64

# %%
sns.pairplot(data=df, x_vars=['PER_LEVEL1', 'PER_LEVEL2', "PER_LEVEL3"], y_vars=['PER_LEVEL1', 'PER_LEVEL2'], hue="SUBGROUP_NAME")

# %%
df.dtypes
# Out:
# INSTITUTION_ID      float64
# ENTITY_CD             int64
# ENTITY_NAME          object
# YEAR                  int64
# SUBJECT              object
# SUBGROUP_NAME        object
# TESTED                int64
# NUM_LEVEL1           object
# PER_LEVEL1            int64
# NUM_LEVEL2           object
# PER_LEVEL2            int64
# NUM_LEVEL3           object
# PER_LEVEL3           object
# NUM_LEVEL4           object
# PER_LEVEL4           object
# NUM_LEVEL5           object
# PER_LEVEL5           object
# NUM_PROF             object
# PER_PROF             object
# TOTAL_EXEMPT        float64
# NUM_EXEMPT_NTEST    float64
# PCT_EXEMPT_NTEST    float64
# NUM_EXEMPT_TEST     float64
# PCT_EXEMPT_TEST     float64
# ASSMNT_FLAG          object
# dtype: object
