# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Getting the two Regents Excel Files

# %%
are_df = pd.read_excel("../Data/SRC2022/Annual Regents Exams.xlsx", nrows=2000)

# %%
are_df.head()
# Out:
#    INSTITUTION_ID     ENTITY_CD       ENTITY_NAME  YEAR  \
# 0    8.000001e+11  151401040000  SCHROON LAKE CSD  2021
# 1    8.000001e+11  151401040000  SCHROON LAKE CSD  2021
# 2    8.000001e+11  151401040000  SCHROON LAKE CSD  2021
# 3    8.000001e+11  151501060000   TICONDEROGA CSD  2021
# 4    8.000001e+11  151501060000   TICONDEROGA CSD  2021
#
#                           SUBJECT               SUBGROUP_NAME  TESTED  \
# 0       Regents Phy Set/Chemistry  Economically Disadvantaged       0
# 1       Regents Phy Set/Earth Sci  Economically Disadvantaged      12
# 2        Regents US History&Gov't  Economically Disadvantaged       0
# 3   Regents Common Core Algebra I                        Male       3
# 4  Regents Common Core Algebra II                        Male       0
#
#   NUM_LEVEL1 PER_LEVEL1 NUM_LEVEL2  ... NUM_LEVEL5 PER_LEVEL5 NUM_PROF  \
# 0          0        NaN          0  ...          0        NaN        0
# ...

# %%
are_df["PER_LEVEL1"].value_counts()
# Out:
# PER_LEVEL1
# s      205
# 08      33
# 13      27
# 10      25
# 05      24
#       ...
# 62       1
# 67       1
# 52       1
# 86       1
# 100      1
# Name: count, Length: 66, dtype: int64

# %%
df = are_df[are_df["YEAR"] == 2021]
# df = df[are_df["SUBGROUP_NAME"].isin(["Male", "Female"])].dropna(subset=["PER_LEVEL1", "PER_LEVEL2"])
df = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])].dropna(subset=["PER_LEVEL1", "PER_LEVEL2"])


sns.scatterplot(data=df, x="NUM_LEVEL1", y="NUM_LEVEL2", hue="SUBGROUP_NAME")
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_14040\4283415333.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])].dropna(subset=["PER_LEVEL1", "PER_LEVEL2"])
# C:\Users\natha\AppData\Local\Temp\ipykernel_14040\4283415333.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[pd.to_numeric(df['PER_LEVEL1'], errors='coerce').notnull()][pd.to_numeric(df['PER_LEVEL2'], errors='coerce').notnull()][are_df["SUBGROUP_NAME"].isin(["Male", "Female"])].dropna(subset=["PER_LEVEL1", "PER_LEVEL2"])
# <Axes: xlabel='NUM_LEVEL1', ylabel='NUM_LEVEL2'>

# %%
df["PER_LEVEL1"].unique()
# Out:
# array(['29', '20', '23', '10', '06', '13', '07', '16', '03', '02', '34',
#        '12', '11', '15', '00', '08', '48', '09', '19', '21', '36', '14',
#        '30', '22', '27', '18', '05', '04', '17', '25', '35', '01', '38'],
#       dtype=object)
